# %% [markdown]
# MODEL IndoBERT

# %%
pip install torch transformers datasets scikit-learn pandas
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)

# %%
import pandas as pd
import numpy as np

df = pd.read_excel("Data_Manual.xlsx")

df.columns = df.columns.str.lower()
df['label'] = df['label'].astype(str).str.strip()
df['label'].replace({'nan': np.nan, '' : np.nan}, inplace=True)

labeled = df[df['label'].notna()]
unlabeled = df[df['label'].isna()]

print("Data berlabel :", len(labeled))
print("Data tidak berlabel :", len(unlabeled))
# Out:
# Data berlabel : 251
# Data tidak berlabel : 817
# /tmp/ipython-input-3149371140.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['label'].replace({'nan': np.nan, '' : np.nan}, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
from datasets import Dataset

lbl_enc = LabelEncoder()
labeled['label_id'] = lbl_enc.fit_transform(labeled['label'])

dataset = Dataset.from_pandas(labeled[['review', 'label_id']])
# Out:
# /tmp/ipython-input-3666564095.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled['label_id'] = lbl_enc.fit_transform(labeled['label'])

# %%
from transformers import AutoTokenizer
from datasets import Features, ClassLabel, Value # Import Features and ClassLabel

tokenizer = AutoTokenizer.from_pretrained("indobenchmark/indobert-base-p1")

def tokenize(batch):
    return tokenizer(batch['review'], truncation=True, padding='max_length', max_length=128)

# Re-initialize dataset from 'labeled' to ensure a consistent starting state
dataset = Dataset.from_pandas(labeled[['review', 'label_id']])

# Conditionally remove the '__index_level_0__' column if it exists
if "__index_level_0__" in dataset.column_names:
    dataset = dataset.remove_columns(["__index_level_0__"])

# Cast 'label_id' to ClassLabel type for stratification and apply other features
features = Features({
    'review': Value(dtype='string'),
    'label_id': ClassLabel(names=lbl_enc.classes_.tolist()) # Convert numpy array to list
})
dataset = dataset.cast(features) # Apply the new features schema

dataset = dataset.train_test_split(test_size=0.2, stratify_by_column="label_id")
dataset = dataset.map(tokenize, batched=True)
dataset = dataset.remove_columns(["review"])
# Rename 'label_id' to 'labels' as expected by the model for training
dataset = dataset.rename_column("label_id", "labels")
dataset.set_format("torch")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Casting the dataset:   0%|          | 0/251 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/51 [00:00<?, ? examples/s]

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer
import torch

model = AutoModelForSequenceClassification.from_pretrained(
    "indobenchmark/indobert-base-p1",
    num_labels=len(lbl_enc.classes_)
)
# Out:
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at indobenchmark/indobert-base-p1 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
args = TrainingArguments(
    output_dir="./sentiment-bert",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=4,
    save_strategy="epoch",
)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
)
trainer.train()
# Out:
# model.safetensors:   0%|          | 0.00/498M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: mawarpratama1204 (mawarpratama1204-universitas-teknologi-yogyakarta) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/content/wandb/run-20251207_103715-sfg8d7bs</code>
# Syncing run <strong><a href='https://wandb.ai/mawarpratama1204-universitas-teknologi-yogyakarta/huggingface/runs/sfg8d7bs' target="_blank">usual-darkness-3</a></strong> to <a href='https://wandb.ai/mawarpratama1204-universitas-teknologi-yogyakarta/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mawarpratama1204-universitas-teknologi-yogyakarta/huggingface' target="_blank">https://wandb.ai/mawarpratama1204-universitas-teknologi-yogyakarta/huggingface</a>
#  View run at <a href='https://wandb.ai/mawarpratama1204-universitas-teknologi-yogyakarta/huggingface/runs/sfg8d7bs' target="_blank">https://wandb.ai/mawarpratama1204-universitas-teknologi-yogyakarta/huggingface/runs/sfg8d7bs</a>
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='52' max='52' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [52/52 23:47, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# TrainOutput(global_step=52, training_loss=0.5516298734224759, metrics={'train_runtime': 1532.2497, 'train_samples_per_second': 0.522, 'train_steps_per_second': 0.034, 'total_flos': 52622683545600.0, 'train_loss': 0.5516298734224759, 'epoch': 4.0})

# %%
from torch.nn.functional import softmax

def predict(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    with torch.no_grad():
        outputs = model(**inputs)
    probs = softmax(outputs.logits, dim=1)
    label_id = torch.argmax(probs).item()
    confidence = torch.max(probs).item()
    return label_id, confidence

pred_labels = []
conf_scores = []

for text in unlabeled['review']:
    label, conf = predict(text)
    pred_labels.append(label)
    conf_scores.append(conf)

unlabeled['label_id'] = pred_labels
unlabeled['confidence'] = conf_scores
# Out:
# /tmp/ipython-input-152810834.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unlabeled['label_id'] = pred_labels
# /tmp/ipython-input-152810834.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unlabeled['confidence'] = conf_scores

# %%
threshold = 0.70
unlabeled.loc[unlabeled['confidence'] >= threshold, 'label'] = \
    lbl_enc.inverse_transform(unlabeled.loc[unlabeled['confidence'] >= threshold, 'label_id'])

# %%
print("Jumlah data yang sudah terlabel:", len(labeled))
# Out:
# Jumlah data yang sudah terlabel: 251

# %%
args = TrainingArguments(
    output_dir="./sentiment-bert",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=4,
    save_strategy="epoch",
)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
)
trainer.train()

# Explicitly save the model and tokenizer after training
trainer.save_model(args.output_dir)
tokenizer.save_pretrained(args.output_dir)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='52' max='52' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [52/52 24:35, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ('./sentiment-bert/tokenizer_config.json',
#  './sentiment-bert/special_tokens_map.json',
#  './sentiment-bert/vocab.txt',
#  './sentiment-bert/added_tokens.json',
#  './sentiment-bert/tokenizer.json')

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import pandas as pd

# Load model yang sudah dilatih
model_path = "./sentiment-bert"
model = AutoModelForSequenceClassification.from_pretrained(model_path)
tokenizer = AutoTokenizer.from_pretrained(model_path)

# Baca dataset
df = pd.read_excel("Data_Manual.xlsx")

# Mapping label (ubah sesuai label saat training)
label_map = {0: "Negatif", 1: "Netral", 2: "Positif"}

# Fungsi prediksi
def predict(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=128)
    with torch.no_grad():
        outputs = model(**inputs)
        probs = torch.softmax(outputs.logits, dim=1)
        label = torch.argmax(probs).item()
        confidence = float(probs[0][label])
    return label, confidence

# Pastikan kolom text ada
if 'text' not in df.columns:
    if 'review' in df.columns:
        df.rename(columns={'review': 'text'}, inplace=True)
    else:
        raise ValueError("Kolom 'text' atau 'review' tidak ditemukan!")

# Tambahkan kolom hasil prediksi
df["predicted_label_id"] = ""
df["predicted_label"] = ""
df["confidence"] = ""

# Loop untuk prediksi tiap baris
for idx, row in df.iterrows():
    label_id, conf = predict(row["text"])
    df.at[idx, "predicted_label_id"] = label_id
    df.at[idx, "predicted_label"] = label_map[label_id]
    df.at[idx, "confidence"] = round(conf, 4)  # biar rapi 4 desimal

# Simpan hasil
output_file = "hasil_final.csv"
df.to_csv(output_file, index=False, encoding="utf-8")

print(f"✔️ Semua data berhasil terlabeli → {output_file}")
# Out:
# ✔️ Semua data berhasil terlabeli → hasil_final.csv

# %% [markdown]
# LLM Groq (llama3.1-8b-instant)

# %%
# !pip install transformers torch pandas groq
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting groq
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.37.1

# %%
from transformers import AutoModelForSequenceClassification, BertTokenizerFast
from groq import Groq
import pandas as pd
import torch
import time

# %%
model_path = "./sentiment-bert"

tokenizer = BertTokenizerFast.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)

label_map = {0: "negatif", 1: "netral", 2: "positif"}

# %%
df = pd.read_csv("hasil_final.csv")

print(df.head())
# Out:
#                                                 text    Label       .1  .2  \
# 0  Harganya naik menjadi 40k krn liburan. Anak2 b...  Negatif  NaN
# 1  Tempat wisata keluarga yang cocok juga untuk e...  Positif  NaN
# 2  Tempat ini bagus untuk berlibur bersama keluar...  Positif  NaN
# 3  Tempat ini lebih ke mini zoo ya sama spot foto...  Positif  NaN
# 4  Tempat mudah ditemukan karena petunjuk jalan y...      NaN  NaN
#
#    .3  .4  .5  .6  predicted_label_id predicted_label  confidence
# 0                                   0         Negatif      0.9946
# 1                                   2         Positif      0.9927
# 2                                   1          Netral      0.9441
# 3                                   2         Positif      0.9271
# 4                                   2         Positif      0.9705

# %%
client = Groq(api_key="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")

# %%
def predict_indobert(text):
    tokens = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        logits = model(**tokens).logits

    prediction = torch.argmax(logits).item()
    return label_map[prediction]

# %%
def refine_with_llm(text, model_label):
    prompt = f"""
Teks: "{text}"

Prediksi awal model: {model_label}

Perbaiki jika salah, jika benar tetap.
Jawab dalam format JSON:
{{
  "label_final": "positif/negatif/netral",
  "alasan": "penjelasan singkat"
}}
"""

    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[{"role": "user", "content": prompt}]
    )

    return response.choices[0].message.content

# %%
results = []

for i, text in enumerate(df["text"]):
    print(f"[{i+1}/{len(df)}] Processing...")

    # Ambil prediksi IndoBERT
    bert_label = predict_indobert(text)
    success = False
    while not success:
        try:
            refined_label = refine_with_llm(text, bert_label)
            success = True
        except Exception as e:
            print("⚠ Rate limit, retrying in 5s...")
            time.sleep(5)

    results.append({
        "text": text,
        "label_bert": bert_label,
        "label_llm": refined_label
    })

    time.sleep(2)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [1/1068] Processing...
# [2/1068] Processing...
# [3/1068] Processing...
# [4/1068] Processing...
# [5/1068] Processing...
# [6/1068] Processing...
# [7/1068] Processing...
# [8/1068] Processing...
# [9/1068] Processing...
# [10/1068] Processing...
# [11/1068] Processing...
# [12/1068] Processing...
# [13/1068] Processing...
# [14/1068] Processing...
# [15/1068] Processing...
# [16/1068] Processing...
# [17/1068] Processing...
# [18/1068] Processing...
# [19/1068] Processing...
# [20/1068] Processing...
# [21/1068] Processing...
# [22/1068] Processing...
# [23/1068] Processing...
# [24/1068] Processing...
# [25/1068] Processing...
# [26/1068] Processing...
# [27/1068] Processing...
# [28/1068] Processing...
# [29/1068] Processing...
# [30/1068] Processing...
# [31/1068] Processing...
# [32/1068] Processing...
# [33/1068] Processing...
# [34/1068] Processing...
# [35/1068] Processing...
# [36/1068] Processing...
# [37/1068] Processing...
# [38/1068] Processing...
# [39/1068] Processing...
# [40/1068] Processing...
# [41/1068] Processing...
# [42/1068] Processing...
# [43/1068] Processing...
# [44/1068] Processing...
# [45/1068] Processing...
# [46/1068] Processing...
# [47/1068] Processing...
# [48/1068] Processing...
# [49/1068] Processing...
# [50/1068] Processing...
# [51/1068] Processing...
# [52/1068] Processing...
# [53/1068] Processing...
# [54/1068] Processing...
# [55/1068] Processing...
# [56/1068] Processing...
# [57/1068] Processing...
# [58/1068] Processing...
# [59/1068] Processing...
# [60/1068] Processing...
# [61/1068] Processing...
# [62/1068] Processing...
# [63/1068] Processing...
# [64/1068] Processing...
# [65/1068] Processing...
# [66/1068] Processing...
# [67/1068] Processing...
# [68/1068] Processing...
# [69/1068] Processing...
# [70/1068] Processing...
# [71/1068] Processing...
# [72/1068] Processing...
# [73/1068] Processing...
# [74/1068] Processing...
# [75/1068] Processing...
# [76/1068] Processing...
# [77/1068] Processing...
# [78/1068] Processing...
# [79/1068] Processing...
# [80/1068] Processing...
# [81/1068] Processing...
# [82/1068] Processing...
# [83/1068] Processing...
# [84/1068] Processing...
# [85/1068] Processing...
# [86/1068] Processing...
# [87/1068] Processing...
# [88/1068] Processing...
# [89/1068] Processing...
# [90/1068] Processing...
# [91/1068] Processing...
# [92/1068] Processing...
# [93/1068] Processing...
# [94/1068] Processing...
# [95/1068] Processing...
# [96/1068] Processing...
# [97/1068] Processing...
# [98/1068] Processing...
# [99/1068] Processing...
# [100/1068] Processing...
# [101/1068] Processing...
# [102/1068] Processing...
# [103/1068] Processing...
# [104/1068] Processing...
# [105/1068] Processing...
# [106/1068] Processing...
# [107/1068] Processing...
# [108/1068] Processing...
# [109/1068] Processing...
# [110/1068] Processing...
# [111/1068] Processing...
# [112/1068] Processing...
# [113/1068] Processing...
# [114/1068] Processing...
# [115/1068] Processing...
# [116/1068] Processing...
# [117/1068] Processing...
# [118/1068] Processing...
# [119/1068] Processing...
# [120/1068] Processing...
# [121/1068] Processing...
# [122/1068] Processing...
# [123/1068] Processing...
# [124/1068] Processing...
# [125/1068] Processing...
# [126/1068] Processing...
# [127/1068] Processing...
# [128/1068] Processing...
# [129/1068] Processing...
# [130/1068] Processing...
# [131/1068] Processing...
# [132/1068] Processing...
# [133/1068] Processing...
# [134/1068] Processing...
# [135/1068] Processing...
# [136/1068] Processing...
# [137/1068] Processing...
# [138/1068] Processing...
# [139/1068] Processing...
# [140/1068] Processing...
# [141/1068] Processing...
# [142/1068] Processing...
# [143/1068] Processing...
# [144/1068] Processing...
# [145/1068] Processing...
# [146/1068] Processing...
# [147/1068] Processing...
# [148/1068] Processing...
# [149/1068] Processing...
# [150/1068] Processing...
# [151/1068] Processing...
# [152/1068] Processing...
# [153/1068] Processing...
# [154/1068] Processing...
# [155/1068] Processing...
# [156/1068] Processing...
# [157/1068] Processing...
# [158/1068] Processing...
# [159/1068] Processing...
# [160/1068] Processing...
# [161/1068] Processing...
# [162/1068] Processing...
# [163/1068] Processing...
# [164/1068] Processing...
# [165/1068] Processing...
# [166/1068] Processing...
# [167/1068] Processing...
# [168/1068] Processing...
# [169/1068] Processing...
# [170/1068] Processing...
# [171/1068] Processing...
# [172/1068] Processing...
# [173/1068] Processing...
# [174/1068] Processing...
# [175/1068] Processing...
# [176/1068] Processing...
# [177/1068] Processing...
# [178/1068] Processing...
# [179/1068] Processing...
# [180/1068] Processing...
# [181/1068] Processing...
# [182/1068] Processing...
# [183/1068] Processing...
# [184/1068] Processing...
# [185/1068] Processing...
# [186/1068] Processing...
# [187/1068] Processing...
# [188/1068] Processing...
# [189/1068] Processing...
# [190/1068] Processing...
# [191/1068] Processing...
# [192/1068] Processing...
# [193/1068] Processing...
# [194/1068] Processing...
# [195/1068] Processing...
# [196/1068] Processing...
# [197/1068] Processing...
# [198/1068] Processing...
# [199/1068] Processing...
# [200/1068] Processing...
# [201/1068] Processing...
# [202/1068] Processing...
# [203/1068] Processing...
# [204/1068] Processing...
# [205/1068] Processing...
# [206/1068] Processing...
# [207/1068] Processing...
# [208/1068] Processing...
# [209/1068] Processing...
# [210/1068] Processing...
# [211/1068] Processing...
# [212/1068] Processing...
# [213/1068] Processing...
# [214/1068] Processing...
# [215/1068] Processing...
# [216/1068] Processing...
# [217/1068] Processing...
# [218/1068] Processing...
# [219/1068] Processing...
# [220/1068] Processing...
# [221/1068] Processing...
# [222/1068] Processing...
# [223/1068] Processing...
# [224/1068] Processing...
# [225/1068] Processing...
# [226/1068] Processing...
# [227/1068] Processing...
# [228/1068] Processing...
# [229/1068] Processing...
# [230/1068] Processing...
# [231/1068] Processing...
# [232/1068] Processing...
# [233/1068] Processing...
# [234/1068] Processing...
# [235/1068] Processing...
# [236/1068] Processing...
# [237/1068] Processing...
# [238/1068] Processing...
# [239/1068] Processing...
# [240/1068] Processing...
# [241/1068] Processing...
# [242/1068] Processing...
# [243/1068] Processing...
# [244/1068] Processing...
# [245/1068] Processing...
# [246/1068] Processing...
# [247/1068] Processing...
# [248/1068] Processing...
# [249/1068] Processing...
# [250/1068] Processing...
# [251/1068] Processing...
# [252/1068] Processing...
# [253/1068] Processing...
# [254/1068] Processing...
# [255/1068] Processing...
# [256/1068] Processing...
# [257/1068] Processing...
# [258/1068] Processing...
# [259/1068] Processing...
# [260/1068] Processing...
# [261/1068] Processing...
# [262/1068] Processing...
# [263/1068] Processing...
# [264/1068] Processing...
# [265/1068] Processing...
# [266/1068] Processing...
# [267/1068] Processing...
# [268/1068] Processing...
# [269/1068] Processing...
# [270/1068] Processing...
# [271/1068] Processing...
# [272/1068] Processing...
# [273/1068] Processing...
# [274/1068] Processing...
# [275/1068] Processing...
# [276/1068] Processing...
# [277/1068] Processing...
# [278/1068] Processing...
# [279/1068] Processing...
# [280/1068] Processing...
# [281/1068] Processing...
# [282/1068] Processing...
# [283/1068] Processing...
# [284/1068] Processing...
# [285/1068] Processing...
# [286/1068] Processing...
# [287/1068] Processing...
# [288/1068] Processing...
# [289/1068] Processing...
# [290/1068] Processing...
# [291/1068] Processing...
# [292/1068] Processing...
# [293/1068] Processing...
# [294/1068] Processing...
# [295/1068] Processing...
# [296/1068] Processing...
# [297/1068] Processing...
# [298/1068] Processing...
# [299/1068] Processing...
# [300/1068] Processing...
# [301/1068] Processing...
# [302/1068] Processing...
# [303/1068] Processing...
# [304/1068] Processing...
# [305/1068] Processing...
# [306/1068] Processing...
# [307/1068] Processing...
# [308/1068] Processing...
# [309/1068] Processing...
# [310/1068] Processing...
# [311/1068] Processing...
# [312/1068] Processing...
# [313/1068] Processing...
# [314/1068] Processing...
# [315/1068] Processing...
# [316/1068] Processing...
# [317/1068] Processing...
# [318/1068] Processing...
# [319/1068] Processing...
# [320/1068] Processing...
# [321/1068] Processing...
# [322/1068] Processing...
# [323/1068] Processing...
# [324/1068] Processing...
# [325/1068] Processing...
# [326/1068] Processing...
# [327/1068] Processing...
# [328/1068] Processing...
# [329/1068] Processing...
# [330/1068] Processing...
# [331/1068] Processing...
# [332/1068] Processing...
# [333/1068] Processing...
# [334/1068] Processing...
# [335/1068] Processing...
# [336/1068] Processing...
# [337/1068] Processing...
# [338/1068] Processing...
# [339/1068] Processing...
# [340/1068] Processing...
# [341/1068] Processing...
# [342/1068] Processing...
# [343/1068] Processing...
# [344/1068] Processing...
# [345/1068] Processing...
# [346/1068] Processing...
# [347/1068] Processing...
# [348/1068] Processing...
# [349/1068] Processing...
# [350/1068] Processing...
# [351/1068] Processing...
# [352/1068] Processing...
# [353/1068] Processing...
# [354/1068] Processing...
# [355/1068] Processing...
# [356/1068] Processing...
# [357/1068] Processing...
# [358/1068] Processing...
# [359/1068] Processing...
# [360/1068] Processing...
# [361/1068] Processing...
# [362/1068] Processing...
# [363/1068] Processing...
# [364/1068] Processing...
# [365/1068] Processing...
# [366/1068] Processing...
# [367/1068] Processing...
# [368/1068] Processing...
# [369/1068] Processing...
# [370/1068] Processing...
# [371/1068] Processing...
# [372/1068] Processing...
# [373/1068] Processing...
# [374/1068] Processing...
# [375/1068] Processing...
# [376/1068] Processing...
# [377/1068] Processing...
# [378/1068] Processing...
# [379/1068] Processing...
# [380/1068] Processing...
# [381/1068] Processing...
# [382/1068] Processing...
# [383/1068] Processing...
# [384/1068] Processing...
# [385/1068] Processing...
# [386/1068] Processing...
# [387/1068] Processing...
# [388/1068] Processing...
# [389/1068] Processing...
# [390/1068] Processing...
# [391/1068] Processing...
# [392/1068] Processing...
# [393/1068] Processing...
# [394/1068] Processing...
# [395/1068] Processing...
# [396/1068] Processing...
# [397/1068] Processing...
# [398/1068] Processing...
# [399/1068] Processing...
# [400/1068] Processing...
# [401/1068] Processing...
# [402/1068] Processing...
# [403/1068] Processing...
# [404/1068] Processing...
# [405/1068] Processing...
# [406/1068] Processing...
# [407/1068] Processing...
# [408/1068] Processing...
# [409/1068] Processing...
# [410/1068] Processing...
# [411/1068] Processing...
# [412/1068] Processing...
# [413/1068] Processing...
# [414/1068] Processing...
# [415/1068] Processing...
# [416/1068] Processing...
# [417/1068] Processing...
# [418/1068] Processing...
# [419/1068] Processing...
# [420/1068] Processing...
# [421/1068] Processing...
# [422/1068] Processing...
# [423/1068] Processing...
# [424/1068] Processing...
# [425/1068] Processing...
# [426/1068] Processing...
# [427/1068] Processing...
# [428/1068] Processing...
# [429/1068] Processing...
# [430/1068] Processing...
# [431/1068] Processing...
# [432/1068] Processing...
# [433/1068] Processing...
# [434/1068] Processing...
# [435/1068] Processing...
# [436/1068] Processing...
# [437/1068] Processing...
# [438/1068] Processing...
# [439/1068] Processing...
# [440/1068] Processing...
# [441/1068] Processing...
# [442/1068] Processing...
# [443/1068] Processing...
# [444/1068] Processing...
# [445/1068] Processing...
# [446/1068] Processing...
# [447/1068] Processing...
# [448/1068] Processing...
# [449/1068] Processing...
# [450/1068] Processing...
# [451/1068] Processing...
# [452/1068] Processing...
# [453/1068] Processing...
# [454/1068] Processing...
# [455/1068] Processing...
# [456/1068] Processing...
# [457/1068] Processing...
# [458/1068] Processing...
# [459/1068] Processing...
# [460/1068] Processing...
# [461/1068] Processing...
# [462/1068] Processing...
# [463/1068] Processing...
# [464/1068] Processing...
# [465/1068] Processing...
# [466/1068] Processing...
# [467/1068] Processing...
# [468/1068] Processing...
# [469/1068] Processing...
# [470/1068] Processing...
# [471/1068] Processing...
# [472/1068] Processing...
# [473/1068] Processing...
# [474/1068] Processing...
# [475/1068] Processing...
# [476/1068] Processing...
# [477/1068] Processing...
# [478/1068] Processing...
# [479/1068] Processing...
# [480/1068] Processing...
# [481/1068] Processing...
# [482/1068] Processing...
# [483/1068] Processing...
# [484/1068] Processing...
# [485/1068] Processing...
# [486/1068] Processing...
# [487/1068] Processing...
# [488/1068] Processing...
# [489/1068] Processing...
# [490/1068] Processing...
# [491/1068] Processing...
# [492/1068] Processing...
# [493/1068] Processing...
# [494/1068] Processing...
# [495/1068] Processing...
# [496/1068] Processing...
# [497/1068] Processing...
# [498/1068] Processing...
# [499/1068] Processing...
# [500/1068] Processing...
# [501/1068] Processing...
# [502/1068] Processing...
# [503/1068] Processing...
# [504/1068] Processing...
# [505/1068] Processing...
# [506/1068] Processing...
# [507/1068] Processing...
# [508/1068] Processing...
# [509/1068] Processing...
# [510/1068] Processing...
# [511/1068] Processing...
# [512/1068] Processing...
# [513/1068] Processing...
# [514/1068] Processing...
# [515/1068] Processing...
# [516/1068] Processing...
# [517/1068] Processing...
# [518/1068] Processing...
# [519/1068] Processing...
# [520/1068] Processing...
# [521/1068] Processing...
# [522/1068] Processing...
# [523/1068] Processing...
# [524/1068] Processing...
# [525/1068] Processing...
# [526/1068] Processing...
# [527/1068] Processing...
# [528/1068] Processing...
# [529/1068] Processing...
# [530/1068] Processing...
# [531/1068] Processing...
# [532/1068] Processing...
# [533/1068] Processing...
# [534/1068] Processing...
# [535/1068] Processing...
# [536/1068] Processing...
# [537/1068] Processing...
# [538/1068] Processing...
# [539/1068] Processing...
# [540/1068] Processing...
# [541/1068] Processing...
# [542/1068] Processing...
# [543/1068] Processing...
# [544/1068] Processing...
# [545/1068] Processing...
# [546/1068] Processing...
# [547/1068] Processing...
# [548/1068] Processing...
# [549/1068] Processing...
# [550/1068] Processing...
# [551/1068] Processing...
# [552/1068] Processing...
# [553/1068] Processing...
# [554/1068] Processing...
# [555/1068] Processing...
# [556/1068] Processing...
# [557/1068] Processing...
# [558/1068] Processing...
# [559/1068] Processing...
# [560/1068] Processing...
# [561/1068] Processing...
# [562/1068] Processing...
# [563/1068] Processing...
# [564/1068] Processing...
# [565/1068] Processing...
# [566/1068] Processing...
# [567/1068] Processing...
# [568/1068] Processing...
# [569/1068] Processing...
# [570/1068] Processing...
# [571/1068] Processing...
# [572/1068] Processing...
# [573/1068] Processing...
# [574/1068] Processing...
# [575/1068] Processing...
# [576/1068] Processing...
# [577/1068] Processing...
# [578/1068] Processing...
# [579/1068] Processing...
# [580/1068] Processing...
# [581/1068] Processing...
# [582/1068] Processing...
# [583/1068] Processing...
# [584/1068] Processing...
# [585/1068] Processing...
# [586/1068] Processing...
# [587/1068] Processing...
# [588/1068] Processing...
# [589/1068] Processing...
# [590/1068] Processing...
# [591/1068] Processing...
# [592/1068] Processing...
# [593/1068] Processing...
# [594/1068] Processing...
# [595/1068] Processing...
# [596/1068] Processing...
# [597/1068] Processing...
# [598/1068] Processing...
# [599/1068] Processing...
# [600/1068] Processing...
# [601/1068] Processing...
# [602/1068] Processing...
# [603/1068] Processing...
# [604/1068] Processing...
# [605/1068] Processing...
# [606/1068] Processing...
# [607/1068] Processing...
# [608/1068] Processing...
# [609/1068] Processing...
# [610/1068] Processing...
# [611/1068] Processing...
# [612/1068] Processing...
# [613/1068] Processing...
# [614/1068] Processing...
# [615/1068] Processing...
# [616/1068] Processing...
# [617/1068] Processing...
# [618/1068] Processing...
# [619/1068] Processing...
# [620/1068] Processing...
# [621/1068] Processing...
# [622/1068] Processing...
# [623/1068] Processing...
# [624/1068] Processing...
# [625/1068] Processing...
# [626/1068] Processing...
# [627/1068] Processing...
# [628/1068] Processing...
# [629/1068] Processing...
# [630/1068] Processing...
# [631/1068] Processing...
# [632/1068] Processing...
# [633/1068] Processing...
# [634/1068] Processing...
# [635/1068] Processing...
# [636/1068] Processing...
# [637/1068] Processing...
# [638/1068] Processing...
# [639/1068] Processing...
# [640/1068] Processing...
# [641/1068] Processing...
# [642/1068] Processing...
# [643/1068] Processing...
# [644/1068] Processing...
# [645/1068] Processing...
# [646/1068] Processing...
# [647/1068] Processing...
# [648/1068] Processing...
# [649/1068] Processing...
# [650/1068] Processing...
# [651/1068] Processing...
# [652/1068] Processing...
# [653/1068] Processing...
# [654/1068] Processing...
# [655/1068] Processing...
# [656/1068] Processing...
# [657/1068] Processing...
# [658/1068] Processing...
# [659/1068] Processing...
# [660/1068] Processing...
# [661/1068] Processing...
# [662/1068] Processing...
# [663/1068] Processing...
# [664/1068] Processing...
# [665/1068] Processing...
# [666/1068] Processing...
# [667/1068] Processing...
# [668/1068] Processing...
# [669/1068] Processing...
# [670/1068] Processing...
# [671/1068] Processing...
# [672/1068] Processing...
# [673/1068] Processing...
# [674/1068] Processing...
# [675/1068] Processing...
# [676/1068] Processing...
# [677/1068] Processing...
# [678/1068] Processing...
# [679/1068] Processing...
# [680/1068] Processing...
# [681/1068] Processing...
# [682/1068] Processing...
# [683/1068] Processing...
# [684/1068] Processing...
# [685/1068] Processing...
# [686/1068] Processing...
# [687/1068] Processing...
# [688/1068] Processing...
# [689/1068] Processing...
# [690/1068] Processing...
# [691/1068] Processing...
# [692/1068] Processing...
# [693/1068] Processing...
# [694/1068] Processing...
# [695/1068] Processing...
# [696/1068] Processing...
# [697/1068] Processing...
# [698/1068] Processing...
# [699/1068] Processing...
# [700/1068] Processing...
# [701/1068] Processing...
# [702/1068] Processing...
# [703/1068] Processing...
# [704/1068] Processing...
# [705/1068] Processing...
# [706/1068] Processing...
# [707/1068] Processing...
# [708/1068] Processing...
# [709/1068] Processing...
# [710/1068] Processing...
# [711/1068] Processing...
# [712/1068] Processing...
# [713/1068] Processing...
# [714/1068] Processing...
# [715/1068] Processing...
# [716/1068] Processing...
# [717/1068] Processing...
# [718/1068] Processing...
# [719/1068] Processing...
# [720/1068] Processing...
# [721/1068] Processing...
# [722/1068] Processing...
# [723/1068] Processing...
# [724/1068] Processing...
# [725/1068] Processing...
# [726/1068] Processing...
# [727/1068] Processing...
# [728/1068] Processing...
# [729/1068] Processing...
# [730/1068] Processing...
# [731/1068] Processing...
# [732/1068] Processing...
# [733/1068] Processing...
# [734/1068] Processing...
# [735/1068] Processing...
# [736/1068] Processing...
# [737/1068] Processing...
# [738/1068] Processing...
# [739/1068] Processing...
# [740/1068] Processing...
# [741/1068] Processing...
# [742/1068] Processing...
# [743/1068] Processing...
# [744/1068] Processing...
# [745/1068] Processing...
# [746/1068] Processing...
# [747/1068] Processing...
# [748/1068] Processing...
# [749/1068] Processing...
# [750/1068] Processing...
# [751/1068] Processing...
# [752/1068] Processing...
# [753/1068] Processing...
# [754/1068] Processing...
# [755/1068] Processing...
# [756/1068] Processing...
# [757/1068] Processing...
# [758/1068] Processing...
# [759/1068] Processing...
# [760/1068] Processing...
# [761/1068] Processing...
# [762/1068] Processing...
# [763/1068] Processing...
# [764/1068] Processing...
# [765/1068] Processing...
# [766/1068] Processing...
# [767/1068] Processing...
# [768/1068] Processing...
# [769/1068] Processing...
# [770/1068] Processing...
# [771/1068] Processing...
# [772/1068] Processing...
# [773/1068] Processing...
# [774/1068] Processing...
# [775/1068] Processing...
# [776/1068] Processing...
# [777/1068] Processing...
# [778/1068] Processing...
# [779/1068] Processing...
# [780/1068] Processing...
# [781/1068] Processing...
# [782/1068] Processing...
# [783/1068] Processing...
# [784/1068] Processing...
# [785/1068] Processing...
# [786/1068] Processing...
# [787/1068] Processing...
# [788/1068] Processing...
# [789/1068] Processing...
# [790/1068] Processing...
# [791/1068] Processing...
# [792/1068] Processing...
# [793/1068] Processing...
# [794/1068] Processing...
# [795/1068] Processing...
# [796/1068] Processing...
# [797/1068] Processing...
# [798/1068] Processing...
# [799/1068] Processing...
# [800/1068] Processing...
# [801/1068] Processing...
# [802/1068] Processing...
# [803/1068] Processing...
# [804/1068] Processing...
# [805/1068] Processing...
# [806/1068] Processing...
# [807/1068] Processing...
# [808/1068] Processing...
# [809/1068] Processing...
# [810/1068] Processing...
# [811/1068] Processing...
# [812/1068] Processing...
# [813/1068] Processing...
# [814/1068] Processing...
# [815/1068] Processing...
# [816/1068] Processing...
# [817/1068] Processing...
# [818/1068] Processing...
# [819/1068] Processing...
# [820/1068] Processing...
# [821/1068] Processing...
# [822/1068] Processing...
# [823/1068] Processing...
# [824/1068] Processing...
# [825/1068] Processing...
# [826/1068] Processing...
# [827/1068] Processing...
# [828/1068] Processing...
# [829/1068] Processing...
# [830/1068] Processing...
# [831/1068] Processing...
# [832/1068] Processing...
# [833/1068] Processing...
# [834/1068] Processing...
# [835/1068] Processing...
# [836/1068] Processing...
# [837/1068] Processing...
# [838/1068] Processing...
# [839/1068] Processing...
# [840/1068] Processing...
# [841/1068] Processing...
# [842/1068] Processing...
# [843/1068] Processing...
# [844/1068] Processing...
# [845/1068] Processing...
# [846/1068] Processing...
# [847/1068] Processing...
# [848/1068] Processing...
# [849/1068] Processing...
# [850/1068] Processing...
# [851/1068] Processing...
# [852/1068] Processing...
# [853/1068] Processing...
# [854/1068] Processing...
# [855/1068] Processing...
# [856/1068] Processing...
# [857/1068] Processing...
# [858/1068] Processing...
# [859/1068] Processing...
# [860/1068] Processing...
# [861/1068] Processing...
# [862/1068] Processing...
# [863/1068] Processing...
# [864/1068] Processing...
# [865/1068] Processing...
# [866/1068] Processing...
# [867/1068] Processing...
# [868/1068] Processing...
# [869/1068] Processing...
# [870/1068] Processing...
# [871/1068] Processing...
# [872/1068] Processing...
# [873/1068] Processing...
# [874/1068] Processing...
# [875/1068] Processing...
# [876/1068] Processing...
# [877/1068] Processing...
# [878/1068] Processing...
# [879/1068] Processing...
# [880/1068] Processing...
# [881/1068] Processing...
# [882/1068] Processing...
# [883/1068] Processing...
# [884/1068] Processing...
# [885/1068] Processing...
# [886/1068] Processing...
# [887/1068] Processing...
# [888/1068] Processing...
# [889/1068] Processing...
# [890/1068] Processing...
# [891/1068] Processing...
# [892/1068] Processing...
# [893/1068] Processing...
# [894/1068] Processing...
# [895/1068] Processing...
# [896/1068] Processing...
# [897/1068] Processing...
# [898/1068] Processing...
# [899/1068] Processing...
# [900/1068] Processing...
# [901/1068] Processing...
# [902/1068] Processing...
# [903/1068] Processing...
# [904/1068] Processing...
# [905/1068] Processing...
# [906/1068] Processing...
# [907/1068] Processing...
# [908/1068] Processing...
# [909/1068] Processing...
# [910/1068] Processing...
# [911/1068] Processing...
# [912/1068] Processing...
# [913/1068] Processing...
# [914/1068] Processing...
# [915/1068] Processing...
# [916/1068] Processing...
# [917/1068] Processing...
# [918/1068] Processing...
# [919/1068] Processing...
# [920/1068] Processing...
# [921/1068] Processing...
# [922/1068] Processing...
# [923/1068] Processing...
# [924/1068] Processing...
# [925/1068] Processing...
# [926/1068] Processing...
# [927/1068] Processing...
# [928/1068] Processing...
# [929/1068] Processing...
# [930/1068] Processing...
# [931/1068] Processing...
# [932/1068] Processing...
# [933/1068] Processing...
# [934/1068] Processing...
# [935/1068] Processing...
# [936/1068] Processing...
# [937/1068] Processing...
# [938/1068] Processing...
# [939/1068] Processing...
# [940/1068] Processing...
# [941/1068] Processing...
# [942/1068] Processing...
# [943/1068] Processing...
# [944/1068] Processing...
# [945/1068] Processing...
# [946/1068] Processing...
# [947/1068] Processing...
# [948/1068] Processing...
# [949/1068] Processing...
# [950/1068] Processing...
# [951/1068] Processing...
# [952/1068] Processing...
# [953/1068] Processing...
# [954/1068] Processing...
# [955/1068] Processing...
# [956/1068] Processing...
# [957/1068] Processing...
# [958/1068] Processing...
# [959/1068] Processing...
# [960/1068] Processing...
# [961/1068] Processing...
# [962/1068] Processing...
# [963/1068] Processing...
# [964/1068] Processing...
# [965/1068] Processing...
# [966/1068] Processing...
# [967/1068] Processing...
# [968/1068] Processing...
# [969/1068] Processing...
# [970/1068] Processing...
# [971/1068] Processing...
# [972/1068] Processing...
# [973/1068] Processing...
# [974/1068] Processing...
# [975/1068] Processing...
# [976/1068] Processing...
# [977/1068] Processing...
# [978/1068] Processing...
# [979/1068] Processing...
# [980/1068] Processing...
# [981/1068] Processing...
# [982/1068] Processing...
# [983/1068] Processing...
# [984/1068] Processing...
# [985/1068] Processing...
# [986/1068] Processing...
# [987/1068] Processing...
# [988/1068] Processing...
# [989/1068] Processing...
# [990/1068] Processing...
# [991/1068] Processing...
# [992/1068] Processing...
# [993/1068] Processing...
# [994/1068] Processing...
# [995/1068] Processing...
# [996/1068] Processing...
# [997/1068] Processing...
# [998/1068] Processing...
# [999/1068] Processing...
# [1000/1068] Processing...
# [1001/1068] Processing...
# [1002/1068] Processing...
# [1003/1068] Processing...
# [1004/1068] Processing...
# [1005/1068] Processing...
# [1006/1068] Processing...
# [1007/1068] Processing...
# [1008/1068] Processing...
# [1009/1068] Processing...
# [1010/1068] Processing...
# [1011/1068] Processing...
# [1012/1068] Processing...
# [1013/1068] Processing...
# [1014/1068] Processing...
# [1015/1068] Processing...
# [1016/1068] Processing...
# [1017/1068] Processing...
# [1018/1068] Processing...
# [1019/1068] Processing...
# [1020/1068] Processing...
# [1021/1068] Processing...
# [1022/1068] Processing...
# [1023/1068] Processing...
# [1024/1068] Processing...
# [1025/1068] Processing...
# [1026/1068] Processing...
# [1027/1068] Processing...
# [1028/1068] Processing...
# [1029/1068] Processing...
# [1030/1068] Processing...
# [1031/1068] Processing...
# [1032/1068] Processing...
# [1033/1068] Processing...
# [1034/1068] Processing...
# [1035/1068] Processing...
# [1036/1068] Processing...
# [1037/1068] Processing...
# [1038/1068] Processing...
# [1039/1068] Processing...
# [1040/1068] Processing...
# [1041/1068] Processing...
# [1042/1068] Processing...
# [1043/1068] Processing...
# [1044/1068] Processing...
# [1045/1068] Processing...
# [1046/1068] Processing...
# [1047/1068] Processing...
# [1048/1068] Processing...
# [1049/1068] Processing...
# [1050/1068] Processing...
# [1051/1068] Processing...
# [1052/1068] Processing...
# [1053/1068] Processing...
# [1054/1068] Processing...
# [1055/1068] Processing...
# [1056/1068] Processing...
# [1057/1068] Processing...
# [1058/1068] Processing...
# [1059/1068] Processing...
# [1060/1068] Processing...
# [1061/1068] Processing...
# [1062/1068] Processing...
# [1063/1068] Processing...
# [1064/1068] Processing...
# [1065/1068] Processing...
# [1066/1068] Processing...
# [1067/1068] Processing...
# [1068/1068] Processing...

# %%
output_df = pd.DataFrame(results)
output_df.to_csv("self_training.csv", index=False)

print("DONE — saved as self_training.csv")
# Out:
# DONE — saved as self_training.csv

# %%
import json
import torch
import time
import pandas as pd

#  IndoBERT prediction with confidence
def predict_indobert(text):
    tokens = tokenizer(text, return_tensors="pt", truncation=True, padding=True)

    with torch.no_grad():
        logits = model(**tokens).logits

    # Softmax → confidence score
    probs = torch.softmax(logits, dim=1).numpy()[0]
    pred_idx = torch.argmax(logits).item()
    predicted_label = label_map[pred_idx]
    confidence = float(probs[pred_idx])

    return predicted_label, confidence


def refine_with_llm(text, bert_label):
    prompt = f"""
Teks: "{text}"

Prediksi awal model: {bert_label}

Periksa apakah label benar. Jika salah, ubah.
Jawab dalam format JSON:
{{
  "label_final": "positif / negatif / netral",
  "alasan": "penjelasan singkat"
}}
"""

    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[{"role": "user", "content": prompt}]
    )

    content = response.choices[0].message.content

    try:
        parsed = json.loads(content)
        final_label = parsed.get("label_final", "").strip().lower()
        alasan = parsed.get("alasan", "")
    except:
        final_label = "ERROR"
        alasan = "Format LLM tidak sesuai JSON"

    return final_label, alasan, content


# Loop processing
results = []

for i, text in enumerate(df["text"]):
    print(f"[{i+1}/{len(df)}] Processing...")

    indobert_label, conf_score = predict_indobert(text)

    # Retry mechanism if rate limit
    success = False
    while not success:
        try:
            final_label, reason, raw_llm = refine_with_llm(text, indobert_label)
            success = True
        except Exception as e:
            print("⚠ Rate limit or connection error. Retrying in 5s...")
            time.sleep(5)

    # Store result
    results.append({
        "text": text,
        "label_indobert": indobert_label,
        "confidence": round(conf_score, 4),
        "label_llm_final": final_label,
        "alasan_llm": reason,
        "raw_llm_output": raw_llm
    })

    time.sleep(2)

output_df = pd.DataFrame(results)
output_df.to_csv("self_training_enhanced.csv", index=False)

print("DONE — File saved as self_training_enhanced.csv")
# Out:
# [1/1068] Processing...
# [2/1068] Processing...
# [3/1068] Processing...
# [4/1068] Processing...
# [5/1068] Processing...
# [6/1068] Processing...
# [7/1068] Processing...
# [8/1068] Processing...
# [9/1068] Processing...
# [10/1068] Processing...
# [11/1068] Processing...
# [12/1068] Processing...
# [13/1068] Processing...
# [14/1068] Processing...
# [15/1068] Processing...
# [16/1068] Processing...
# [17/1068] Processing...
# [18/1068] Processing...
# [19/1068] Processing...
# [20/1068] Processing...
# [21/1068] Processing...
# [22/1068] Processing...
# [23/1068] Processing...
# [24/1068] Processing...
# [25/1068] Processing...
# [26/1068] Processing...
# [27/1068] Processing...
# [28/1068] Processing...
# [29/1068] Processing...
# [30/1068] Processing...
# [31/1068] Processing...
# [32/1068] Processing...
# [33/1068] Processing...
# [34/1068] Processing...
# [35/1068] Processing...
# [36/1068] Processing...
# [37/1068] Processing...
# [38/1068] Processing...
# [39/1068] Processing...
# [40/1068] Processing...
# [41/1068] Processing...
# [42/1068] Processing...
# [43/1068] Processing...
# [44/1068] Processing...
# [45/1068] Processing...
# [46/1068] Processing...
# [47/1068] Processing...
# [48/1068] Processing...
# [49/1068] Processing...
# [50/1068] Processing...
# [51/1068] Processing...
# [52/1068] Processing...
# [53/1068] Processing...
# [54/1068] Processing...
# [55/1068] Processing...
# [56/1068] Processing...
# [57/1068] Processing...
# [58/1068] Processing...
# [59/1068] Processing...
# [60/1068] Processing...
# [61/1068] Processing...
# [62/1068] Processing...
# [63/1068] Processing...
# [64/1068] Processing...
# [65/1068] Processing...
# [66/1068] Processing...
# [67/1068] Processing...
# [68/1068] Processing...
# [69/1068] Processing...
# [70/1068] Processing...
# [71/1068] Processing...
# [72/1068] Processing...
# [73/1068] Processing...
# [74/1068] Processing...
# [75/1068] Processing...
# [76/1068] Processing...
# [77/1068] Processing...
# [78/1068] Processing...
# [79/1068] Processing...
# [80/1068] Processing...
# [81/1068] Processing...
# [82/1068] Processing...
# [83/1068] Processing...
# [84/1068] Processing...
# [85/1068] Processing...
# [86/1068] Processing...
# [87/1068] Processing...
# [88/1068] Processing...
# [89/1068] Processing...
# [90/1068] Processing...
# [91/1068] Processing...
# [92/1068] Processing...
# [93/1068] Processing...
# [94/1068] Processing...
# [95/1068] Processing...
# [96/1068] Processing...
# [97/1068] Processing...
# [98/1068] Processing...
# [99/1068] Processing...
# [100/1068] Processing...
# [101/1068] Processing...
# [102/1068] Processing...
# [103/1068] Processing...
# [104/1068] Processing...
# [105/1068] Processing...
# [106/1068] Processing...
# [107/1068] Processing...
# [108/1068] Processing...
# [109/1068] Processing...
# [110/1068] Processing...
# [111/1068] Processing...
# [112/1068] Processing...
# [113/1068] Processing...
# [114/1068] Processing...
# [115/1068] Processing...
# [116/1068] Processing...
# [117/1068] Processing...
# [118/1068] Processing...
# [119/1068] Processing...
# [120/1068] Processing...
# [121/1068] Processing...
# [122/1068] Processing...
# [123/1068] Processing...
# [124/1068] Processing...
# [125/1068] Processing...
# [126/1068] Processing...
# [127/1068] Processing...
# [128/1068] Processing...
# [129/1068] Processing...
# [130/1068] Processing...
# [131/1068] Processing...
# [132/1068] Processing...
# [133/1068] Processing...
# [134/1068] Processing...
# [135/1068] Processing...
# [136/1068] Processing...
# [137/1068] Processing...
# [138/1068] Processing...
# [139/1068] Processing...
# [140/1068] Processing...
# [141/1068] Processing...
# [142/1068] Processing...
# [143/1068] Processing...
# [144/1068] Processing...
# [145/1068] Processing...
# [146/1068] Processing...
# [147/1068] Processing...
# [148/1068] Processing...
# [149/1068] Processing...
# [150/1068] Processing...
# [151/1068] Processing...
# [152/1068] Processing...
# [153/1068] Processing...
# [154/1068] Processing...
# [155/1068] Processing...
# [156/1068] Processing...
# [157/1068] Processing...
# [158/1068] Processing...
# [159/1068] Processing...
# [160/1068] Processing...
# [161/1068] Processing...
# [162/1068] Processing...
# [163/1068] Processing...
# [164/1068] Processing...
# [165/1068] Processing...
# [166/1068] Processing...
# [167/1068] Processing...
# [168/1068] Processing...
# [169/1068] Processing...
# [170/1068] Processing...
# [171/1068] Processing...
# [172/1068] Processing...
# [173/1068] Processing...
# [174/1068] Processing...
# [175/1068] Processing...
# [176/1068] Processing...
# [177/1068] Processing...
# [178/1068] Processing...
# [179/1068] Processing...
# [180/1068] Processing...
# [181/1068] Processing...
# [182/1068] Processing...
# [183/1068] Processing...
# [184/1068] Processing...
# [185/1068] Processing...
# [186/1068] Processing...
# [187/1068] Processing...
# [188/1068] Processing...
# [189/1068] Processing...
# [190/1068] Processing...
# [191/1068] Processing...
# [192/1068] Processing...
# [193/1068] Processing...
# [194/1068] Processing...
# [195/1068] Processing...
# [196/1068] Processing...
# [197/1068] Processing...
# [198/1068] Processing...
# [199/1068] Processing...
# [200/1068] Processing...
# [201/1068] Processing...
# [202/1068] Processing...
# [203/1068] Processing...
# [204/1068] Processing...
# [205/1068] Processing...
# [206/1068] Processing...
# [207/1068] Processing...
# [208/1068] Processing...
# [209/1068] Processing...
# [210/1068] Processing...
# [211/1068] Processing...
# [212/1068] Processing...
# [213/1068] Processing...
# [214/1068] Processing...
# [215/1068] Processing...
# [216/1068] Processing...
# [217/1068] Processing...
# [218/1068] Processing...
# [219/1068] Processing...
# [220/1068] Processing...
# [221/1068] Processing...
# [222/1068] Processing...
# [223/1068] Processing...
# [224/1068] Processing...
# [225/1068] Processing...
# [226/1068] Processing...
# [227/1068] Processing...
# [228/1068] Processing...
# [229/1068] Processing...
# [230/1068] Processing...
# [231/1068] Processing...
# [232/1068] Processing...
# [233/1068] Processing...
# [234/1068] Processing...
# [235/1068] Processing...
# [236/1068] Processing...
# [237/1068] Processing...
# [238/1068] Processing...
# [239/1068] Processing...
# [240/1068] Processing...
# [241/1068] Processing...
# [242/1068] Processing...
# [243/1068] Processing...
# [244/1068] Processing...
# [245/1068] Processing...
# [246/1068] Processing...
# [247/1068] Processing...
# [248/1068] Processing...
# [249/1068] Processing...
# [250/1068] Processing...
# [251/1068] Processing...
# [252/1068] Processing...
# [253/1068] Processing...
# [254/1068] Processing...
# [255/1068] Processing...
# [256/1068] Processing...
# [257/1068] Processing...
# [258/1068] Processing...
# [259/1068] Processing...
# [260/1068] Processing...
# [261/1068] Processing...
# [262/1068] Processing...
# [263/1068] Processing...
# [264/1068] Processing...
# [265/1068] Processing...
# [266/1068] Processing...
# [267/1068] Processing...
# [268/1068] Processing...
# [269/1068] Processing...
# [270/1068] Processing...
# [271/1068] Processing...
# [272/1068] Processing...
# [273/1068] Processing...
# [274/1068] Processing...
# [275/1068] Processing...
# [276/1068] Processing...
# [277/1068] Processing...
# [278/1068] Processing...
# [279/1068] Processing...
# [280/1068] Processing...
# [281/1068] Processing...
# [282/1068] Processing...
# [283/1068] Processing...

# %%
import pandas as pd

df = pd.read_csv("self_training_enhanced.csv")

print(df.head())

import pandas as pd
from tabulate import tabulate

# Menampilkan tabel rapi
print(tabulate(df, headers='keys', tablefmt='grid', showindex=False))

# Simpan ke CSV baru dengan format rapi
df.to_csv("self_training_.csv", index=False)

print("\n✔ File rapi telah disimpan sebagai: self_training_.csv")
